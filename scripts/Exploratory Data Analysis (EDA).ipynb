# %% [markdown]
# # Lung Cancer Prediction - Exploratory Data Analysis (EDA)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
# Load the dataset
df = pd.read_csv('lung cancer data.csv')

# %%
# Clean column names
df.columns = df.columns.str.strip().str.replace(' ', '_').str.upper()

# %%
# Encode Categorical for Visualization
df['GENDER'] = df['GENDER'].map({'F': 0, 'M': 1})
df['LUNG_CANCER'] = df['LUNG_CANCER'].map({'NO': 0, 'YES': 1})

# %%
# 🔹 Distribution of Lung Cancer Cases
sns.countplot(x='LUNG_CANCER', data=df)
plt.title('Distribution of Lung Cancer Cases')
plt.xlabel('Lung Cancer (1=Yes, 0=No)')
plt.ylabel('Count')
plt.show()

# %%
# 🔹 Correlation Heatmap
plt.figure(figsize=(12,8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# 🔹 Age Distribution by Cancer Status
sns.boxplot(x='LUNG_CANCER', y='AGE', data=df)
plt.title('Age vs Lung Cancer')
plt.show()

# %%
# 🔹 Pairplot
sns.pairplot(df, hue='LUNG_CANCER')
plt.show()

# %%
# 🔹 Gender vs Lung Cancer
sns.countplot(x='GENDER', hue='LUNG_CANCER', data=df)
plt.title('Gender vs Lung Cancer')
plt.xlabel('Gender (0=Female, 1=Male)')
plt.ylabel('Count')
plt.show()

# %%
# 🔹 Smoking vs Lung Cancer
sns.countplot(x='SMOKING', hue='LUNG_CANCER', data=df)
plt.title('Smoking History vs Lung Cancer')
plt.xlabel('Smoking (1=Yes, 0=No)')
plt.ylabel('Count')
plt.show()

# %%
print("\n✅ EDA complete. Ready to train models!")
# Out:
# ✅ EDA complete. Ready to train models!
